# %% [markdown]
# # Working Title:

# %% [markdown]
# Question:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Let's import the data and have a looksie

# %%
data = pd.read_csv('analytic_data2019.csv', header=[0,1])

# %%
# df1 = healthrank_data.parse()
# Out:
#   State FIPS Code County FIPS Code 5-digit FIPS Code State Abbreviation  \
#         statecode       countycode          fipscode              state
# 0               0                0                 0                 US
# 1               1                0              1000                 AL
# 2               1                1              1001                 AL
# 3               1                3              1003                 AL
# 4               1                5              1005                 AL
#
#              Name Release Year County Ranked (Yes=1/No=0)  \
#            county         year              county_ranked
# 0   United States         2019                        NaN
# 1         Alabama         2019                        NaN
# 2  Autauga County         2019                        1.0
# 3  Baldwin County         2019                        1.0
# 4  Barbour County         2019                        1.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3195 entries, 0 to 3194
# Columns: 534 entries, State FIPS Code to Population growth raw value
# dtypes: object(534)
# memory usage: 13.0+ MB

# %%
# healthrank_data = pd.ExcelFile('2019 County Health Rankings Data - v2.xls')

xl = pd.ExcelFile('2019 County Health Rankings Data - v2.xls')
sheets = xl.sheet_names
df1 = xl.parse(sheets[1], skiprows=1)
df2 = xl.parse(sheets[2], skiprows=1)
df3 = xl.parse(sheets[3], skiprows=1)
df4 = xl.parse(sheets[4], skiprows=1)
df5 = xl.parse(sheets[5], skiprows=1)
df6 = xl.parse(sheets[6], skiprows=1)

df5.head()
# Out:
#    FIPS    State   County  Life Expectancy  95% CI - Low  95% CI - High  \
# 0  1001  Alabama  Autauga        76.330589     75.554117      77.107061
# 1  1003  Alabama  Baldwin        78.599498     78.208357      78.990639
# 2  1005  Alabama  Barbour        75.779457     74.639355      76.919559
# 3  1007  Alabama     Bibb        73.928271     72.624611      75.231931
# 4  1009  Alabama   Blount        74.597767     73.810999      75.384535
#
#    Life Expectancy (Black)  Life Expectancy (Hispanic)  \
# 0                74.600628                         NaN
# 1                75.628919                   98.039893
# 2                74.240228                         NaN
# 3                72.294686                         NaN
# 4                      NaN                   78.577094
#
#    Life Expectancy (White)  # Deaths  ...  % Hispanic  # Non-Hispanic White  \
# 0                76.337219     815.0  ...    2.857452                 41336
# ...

# %%
# Trying to get a full table from the sheets in the excel file:
sheets_dict = pd.read_excel('2019 County Health Rankings Data - v2.xls', header=[1], sheet_name=None)

full_table = pd.DataFrame()
for name, sheet in sheets_dict.items():
    sheet['sheet'] = name
    sheet = sheet.rename(columns=lambda x: x.split('\n')[-1])
    full_table = full_table.append(sheet)

full_table.reset_index(inplace=True, drop=True)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12841 entries, 0 to 12840
# Columns: 252 entries, # African American to sheet
# dtypes: float64(191), object(61)
# memory usage: 24.7+ MB

# %%
# Out:
# Index(['# African American', '# Alcohol-Impaired Driving Deaths',
#        '# American Indian/Alaskan Native', '# Asian', '# Associations',
#        '# Chlamydia Cases', '# Deaths', '# Deaths.1', '# Deaths.2',
#        '# Dentists',
#        ...
#        'Unnamed: 2', 'Unreliable', 'Violent Crime Rate', 'Weight',
#        'YPLL Rate (Black)', 'YPLL Rate (Hispanic)', 'YPLL Rate (White)',
#        'Year(s)', 'Years of Potential Life Lost Rate', 'sheet'],
#       dtype='object', length=252)
